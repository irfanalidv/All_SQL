# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

chipo = pd.read_csv(url, sep = '\t')

# %%
chipo.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Which was the most-ordered item? 
chipo.groupby('item_name').sum().sort_values(['quantity'],ascending = False).head(5)
# Out:
#                      order_id  quantity
# item_name
# Chicken Bowl           713926       761
# Chicken Burrito        497303       591
# Chips and Guacamole    449959       506
# Steak Burrito          328437       386
# Canned Soft Drink      304753       351

# %%
#What was the most ordered item in the choice_description column?
chipo.groupby('choice_description').sum().sort_values(['quantity'], ascending = False).head(5)
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42

# %%
#How many items were orderd in total?
chipo.quantity.sum()
# Out:
# 4972

# %%
#How much was the revenue for the period in the dataset?
print('Revenue is: $' + str(np.round((chipo['quantity']*chipo['item_price'].str.replace('$', '').astype('float')).sum(),2)))
# Out:
# Revenue is: $39237.02

# %%
#How many orders were made in the period?
chipo.order_id.value_counts().count()
# Out:
# 1834

# %%
#What is the average revenue amount per order?
chipo['revenue'] = np.round((chipo['quantity']*chipo['item_price'].str.replace('$', '').astype('float')),2)

# %%
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped.head(5)
# Out:
#           quantity  revenue
# order_id
# 1                4    11.56
# 2                2    33.96
# 3                2    12.67
# 4                2    21.00
# 5                2    13.70

# %%
np.round(order_grouped.mean()['revenue'],2)
# Out:
# 21.39

# %%
np.round(chipo.groupby(by=['order_id']).sum().mean()['revenue'],2)
# Out:
# 21.39

# %%
#How many different items are sold?
chipo.item_name.value_counts().count()
# Out:
# 50

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')

# %%
users.head(5)
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
users.shape
# Out:
# (943, 4)

# %%
users.columns
# Out:
# Index(['age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
users.occupation.head(5)
# Out:
# user_id
# 1    technician
# 2         other
# 3        writer
# 4    technician
# 5         other
# Name: occupation, dtype: object

# %%
#How many different occupations are in this dataset?
users.occupation.nunique()
# Out:
# 21

# %%
#What is the most frequent occupation?
users.occupation.value_counts().head(5)
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# Name: occupation, dtype: int64

# %%
#Summarize the occupation column
users.occupation.describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %%
#What is the mean age of users?
np.round(users.age.mean(),2)
# Out:
# 34.05

# %%
#What is the age with least occurrence?
users.age.value_counts().tail(5)
# Out:
# 11    1
# 10    1
# 73    1
# 66    1
# 7     1
# Name: age, dtype: int64

# %%
#Filtering and Sorting Data

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv', sep=',')
euro12.head(5)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
euro12.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
discipline = euro12[['Team','Yellow Cards','Red Cards']]
discipline.head(5)
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
#Sort the teams by Red Cards, then to Yellow Cards
discipline.sort_values(['Yellow Cards','Red Cards'],ascending = False).head(5)
# Out:
#         Team  Yellow Cards  Red Cards
# 7      Italy            16          0
# 10  Portugal            12          0
# 13     Spain            11          0
# 6     Greece             9          1
# 0    Croatia             9          0

# %%
# Filter teams that scored more than 6 goals
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#Select the teams that start with G
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#Select the first 7 columns
euro12.iloc[:, :7].head(5)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)
# 0            16.0%                          32
# 1            12.9%                          39
# 2            20.0%                          27
# 3            17.2%                          40
# 4             6.5%                          65

# %%
#Select all columns except the last 3.
euro12.iloc[:,:-3].head(5)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
#Present only the Shooting Accuracy from England, Italy and Russia
euro12.loc[euro12.Team.isin(['England','Italy','Russia']),['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %%
#Select rows where Total shots (inc. Blocked) is greater than  30
euro12['Total shots (inc. Blocked)'].describe()
# Out:
# count     16.000000
# mean      54.937500
# std       26.065223
# min       27.000000
# 25%       36.500000
# 50%       44.000000
# 75%       68.750000
# max      110.000000
# Name: Total shots (inc. Blocked), dtype: float64

# %%
euro12[(euro12['Total shots (inc. Blocked)'] > 60) | (euro12['Total shots (inc. Blocked)'] < 27) ]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 4     France      3               22                24             37.9%
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 4              6.5%                          65             1              0
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
# ...

# %%
#Select all the Team not named "Germany"
euro12[euro12['Team'] != 'Germany'].head(5)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
#Print the mean, min and max values for Total shots (inc. Blocked)

data = euro12.groupby('Team')

# %%
data['Total shots (inc. Blocked)'].agg(['mean', 'min', 'max']).head(5)
# Out:
#                 mean  min  max
# Team
# Croatia           32   32   32
# Czech Republic    39   39   39
# Denmark           27   27   27
# England           40   40   40
# France            65   65   65

# %%
users.head(5)
# Out:
#          age gender  occupation zip_code  gender_n
# user_id
# 1         24      M  technician    85711         0
# 2         53      F       other    94043         1
# 3         23      M      writer    32067         0
# 4         24      M  technician    43537         0
# 5         33      F       other    15213         1

# %%
#Discover the Male ratio per occupation and sort it from the most to the least

def gender_to_numeric(x): 
    if x == 'M':
        return 0
    if x == 'F':
        return 1
    
users['gender_n'] = users['gender'].apply(gender_to_numeric)

# %%
female_profile = users.groupby('occupation').gender_n.sum()/users.occupation.value_counts() *100
female_profile.sort_values(ascending = False).head(5)
# Out:
# homemaker        85.714286
# healthcare       68.750000
# librarian        56.862745
# artist           46.428571
# administrator    45.569620
# dtype: float64

# %%
#For each occupation, calculate the minimum and maximum ages
users.groupby(['occupation','gender']).age.agg(['min','max','mean']).head(5)
# Out:
#                       min  max       mean
# occupation    gender
# administrator F        22   62  40.638889
#               M        21   70  37.162791
# artist        F        19   48  30.307692
#               M        20   45  32.333333
# doctor        M        28   64  43.571429

# %%
#For each occupation present the percentage of women and men
gender_ocup= users.groupby(['occupation','gender']).agg({'gender':'count'})
gender_ocup.head(5)
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7

# %%
occup_count= users.groupby(['occupation']).agg('count')
occup_count.head(5)
# Out:
#                age  gender  zip_code  gender_n
# occupation
# administrator   79      79        79        79
# artist          28      28        28        28
# doctor           7       7         7         7
# educator        95      95        95        95
# engineer        67      67        67        67

# %%
# divide the gender_ocup per the occup_count and multiply per 100
occup_gender = gender_ocup.div(occup_count, level = 'occupation') *100
occup_gender.head()
# Out:
#                       age      gender  gender_n  zip_code
# occupation    gender
# administrator F       NaN   45.569620       NaN       NaN
#               M       NaN   54.430380       NaN       NaN
# artist        F       NaN   46.428571       NaN       NaN
#               M       NaN   53.571429       NaN       NaN
# doctor        M       NaN  100.000000       NaN       NaN

# %%
occup_gender.loc[: , 'gender'].head(5)
#occup_gender.iloc[: , 1:2].head(5)
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# Name: gender, dtype: float64

# %%
#merge
cars1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
cars2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

# %%
cars1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
cars2.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %%
#Oops, it seems our first dataset has some unnamed blank columns, fix cars1
cars1= cars1.loc[:,'mpg':'car']
cars1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car'],
#       dtype='object')

# %%
#Join cars1 and cars2 into a single DataFrame called cars
cars = cars1.append(cars2)
cars.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars['owner_id'] = np.random.randint(13432,high = 120000,size= 398, dtype='int')

# %%
cars.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owner_id
# 0       1  chevrolet chevelle malibu     88485
# 1       1          buick skylark 320    109432
# 2       1         plymouth satellite     38146
# 3       1              amc rebel sst    119636
# 4       1                ford torino     94632

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    int64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car           398 non-null    object
#  9   owner_id      398 non-null    int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 34.2+ KB

# %%
#pd.concat([data1, data2])
#pd.merge(all_data, data3, on='subject_id')

#housemkt.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)

# %%
#stats
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-215-89573e1d2551> in <module>
#       1 #stats
# ----> 2 cars.horsepower.idxmax()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2108         """
#    2109         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2110         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    2111         if i == -1:
#    2112             return np.nan
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      62             if any(self.check(obj) for obj in obj_iter):
#      63                 f_name = f.__name__.replace("nan", "")
# ---> 64                 raise TypeError(
#      65                     f"reduction operation '{f_name}' not allowed for this dtype"
# ...
